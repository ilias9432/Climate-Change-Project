# %%
import pandas as pd
import pandas as pds
import numpy as np

from sklearn.model_selection import train_test_split

# %%
pd.set_option('display.max_rows', None, 'display.max_columns', None)

# %%
url = 'file:///Users/ilyasozgur/Desktop/DataForProject/pr_2020_2039_mavg_rcp26_AUT_BEL_BGR_HRV_CYP_CZE_DNK_EST_FIN_FRA_DEU_GRC_HUN_IRL_LVA_LTU_LUX_MLT_NLD_POL_PRT_ROU_SVK_SVN_ESP_SWE.csv.html'
precip1 = pd.read_csv(url, header = None)
precip1 = precip1.drop([0])
precip1 = precip1.replace({' ': ''}, regex=True)

# %%
precip1.head()
# Out:
#            0          1           2           3        4    5
# 1   79.89857  2020-2039  bcc_csm1_1  JanAverage  Austria  AUT
# 2   64.46793  2020-2039  bcc_csm1_1  FebAverage  Austria  AUT
# 3   72.89026  2020-2039  bcc_csm1_1  MarAverage  Austria  AUT
# 4   71.28545  2020-2039  bcc_csm1_1  AprAverage  Austria  AUT
# 5  67.479836  2020-2039  bcc_csm1_1  MayAverage  Austria  AUT

# %%
precip1.columns =['Precip', 'Year', 'data1', 'Month','Country','Code']

# %%
#precip1 = precip1[['Country','Code']]
#precip1.to_excel('/Users/ilyasozgur/Desktop/Climate_Change/CountryCode/Code.xlsx')

# %%
Precip      = precip1.iloc[:,0:1]
Country     = precip1.iloc[:,4:5]
Month       = precip1.iloc[:,3:4]

precip2 = pd.concat([Precip, Country, Month], axis=1, sort=False)

# %%
list_country = list(precip2['Country'].unique())

# %%
precip2['Country'] = precip2['Country'].replace({' ': ''}, regex=True)

# %%
Austria  = precip2[(precip2['Country']  == 'Austria')]
Belgium  = precip2[(precip2['Country']  == 'Belgium')]
Bulgaria = precip2[(precip2['Country'] == 'Bulgaria')]
Croatia  = precip2[(precip2['Country']  == 'Croatia')]
Cyprus   = precip2[(precip2['Country']   == 'Cyprus')]
CzechRepublic = precip2[(precip2['Country']  == 'CzechRepublic')]
Denmark  = precip2[(precip2['Country']  == 'Denmark')]
Estonia  = precip2[(precip2['Country']  == 'Estonia')]
Finland  = precip2[(precip2['Country']  == 'Finland')]
France   = precip2[(precip2['Country']  == 'France')]
Germany  = precip2[(precip2['Country']  == 'Germany')]
Greece   = precip2[(precip2['Country']  == 'Greece')]
Hungary  = precip2[(precip2['Country']  == 'Hungary')]
Ireland  = precip2[(precip2['Country']  == 'Ireland')]
Latvia   = precip2[(precip2['Country']  == 'Latvia')]
Lithuania   = precip2[(precip2['Country']  == 'Lithuania')]
Luxembourg  = precip2[(precip2['Country']  == 'Luxembourg')]
Malta       = precip2[(precip2['Country']  == 'Malta')]
Netherlands = precip2[(precip2['Country']  == 'Netherlands')]
Poland      = precip2[(precip2['Country']  == 'Poland')]
Portugal    = precip2[(precip2['Country']  == 'Portugal')]
Slovakia    = precip2[(precip2['Country']  == 'Slovakia')]
Slovenia    = precip2[(precip2['Country']  == 'Slovenia')]
Spain       = precip2[(precip2['Country']  == 'Spain')]
Sweden      = precip2[(precip2['Country']  == 'Sweden')]

# %%
Austria['Month2'] = np.arange(len(Austria))
Austria['Year']  = '2020'
Austria['Aggregate Year'] = (Austria['Month2']/12).astype(int)
Austria['Year'] = Austria['Year'].astype(int)
Austria['Year Series'] = Austria['Year'] + Austria['Aggregate Year'] 

Belgium['Month2'] = np.arange(len(Belgium))
Belgium['Year']  = '2020'
Belgium['Aggregate Year'] = (Belgium['Month2']/12).astype(int)
Belgium['Year'] = Belgium['Year'].astype(int)
Belgium['Year Series'] = Belgium['Year'] + Belgium['Aggregate Year'] 

Bulgaria['Month2'] = np.arange(len(Bulgaria))
Bulgaria['Year']  = '2020'
Bulgaria['Aggregate Year'] = (Bulgaria['Month2']/12).astype(int)
Bulgaria['Year'] = Bulgaria['Year'].astype(int)
Bulgaria['Year Series'] = Bulgaria['Year'] + Bulgaria['Aggregate Year'] 

Croatia['Month2'] = np.arange(len(Croatia))
Croatia['Year']  = '2020'
Croatia['Aggregate Year'] = (Croatia['Month2']/12).astype(int)
Croatia['Year'] = Croatia['Year'].astype(int)
Croatia['Year Series'] = Croatia['Year'] + Croatia['Aggregate Year'] 

Cyprus['Month2'] = np.arange(len(Cyprus))
Cyprus['Year']  = '2020'
Cyprus['Aggregate Year'] = (Cyprus['Month2']/12).astype(int)
Cyprus['Year'] = Cyprus['Year'].astype(int)
Cyprus['Year Series'] = Cyprus['Year'] + Cyprus['Aggregate Year'] 

CzechRepublic['Month2'] = np.arange(len(CzechRepublic))
CzechRepublic['Year']  = '2020'
CzechRepublic['Aggregate Year'] = (CzechRepublic['Month2']/12).astype(int)
CzechRepublic['Year'] = CzechRepublic['Year'].astype(int)
CzechRepublic['Year Series'] = CzechRepublic['Year'] + CzechRepublic['Aggregate Year'] 

Denmark['Month2'] = np.arange(len(Denmark))
Denmark['Year']  = '2020'
Denmark['Aggregate Year'] = (Denmark['Month2']/12).astype(int)
Denmark['Year'] = Denmark['Year'].astype(int)
Denmark['Year Series'] = Denmark['Year'] + Denmark['Aggregate Year'] 

Estonia['Month2'] = np.arange(len(Estonia))
Estonia['Year']  = '2020'
Estonia['Aggregate Year'] = (Estonia['Month2']/12).astype(int)
Estonia['Year'] = Estonia['Year'].astype(int)
Estonia['Year Series'] = Estonia['Year'] + Estonia['Aggregate Year'] 

Finland['Month2'] = np.arange(len(Finland))
Finland['Year']  = '2020'
Finland['Aggregate Year'] = (Finland['Month2']/12).astype(int)
Finland['Year'] = Finland['Year'].astype(int)
Finland['Year Series'] = Finland['Year'] + Finland['Aggregate Year'] 

France['Month2'] = np.arange(len(France))
France['Year']  = '2020'
France['Aggregate Year'] = (France['Month2']/12).astype(int)
France['Year'] = France['Year'].astype(int)
France['Year Series'] = France['Year'] + France['Aggregate Year'] 

Germany['Month2'] = np.arange(len(Germany))
Germany['Year']  = '2020'
Germany['Aggregate Year'] = (Germany['Month2']/12).astype(int)
Germany['Year'] = Germany['Year'].astype(int)
Germany['Year Series'] = Germany['Year'] + Germany['Aggregate Year'] 

Greece['Month2'] = np.arange(len(Greece))
Greece['Year']  = '2020'
Greece['Aggregate Year'] = (Greece['Month2']/12).astype(int)
Greece['Year'] = Greece['Year'].astype(int)
Greece['Year Series'] = Greece['Year'] + Greece['Aggregate Year'] 

Hungary['Month2'] = np.arange(len(Hungary))
Hungary['Year']  = '2020'
Hungary['Aggregate Year'] = (Hungary['Month2']/12).astype(int)
Hungary['Year'] = Hungary['Year'].astype(int)
Hungary['Year Series'] = Hungary['Year'] + Hungary['Aggregate Year'] 

Ireland['Month2'] = np.arange(len(Ireland))
Ireland['Year']  = '2020'
Ireland['Aggregate Year'] = (Ireland['Month2']/12).astype(int)
Ireland['Year'] = Ireland['Year'].astype(int)
Ireland['Year Series'] = Ireland['Year'] + Ireland['Aggregate Year'] 

Latvia['Month2'] = np.arange(len(Latvia))
Latvia['Year']  = '2020'
Latvia['Aggregate Year'] = (Latvia['Month2']/12).astype(int)
Latvia['Year'] = Latvia['Year'].astype(int)
Latvia['Year Series'] = Latvia['Year'] + Latvia['Aggregate Year'] 

Lithuania['Month2'] = np.arange(len(Lithuania))
Lithuania['Year']  = '2020'
Lithuania['Aggregate Year'] = (Lithuania['Month2']/12).astype(int)
Lithuania['Year'] = Lithuania['Year'].astype(int)
Lithuania['Year Series'] = Lithuania['Year'] + Lithuania['Aggregate Year'] 

Luxembourg['Month2'] = np.arange(len(Luxembourg))
Luxembourg['Year']  = '2020'
Luxembourg['Aggregate Year'] = (Luxembourg['Month2']/12).astype(int)
Luxembourg['Year'] = Luxembourg['Year'].astype(int)
Luxembourg['Year Series'] = Luxembourg['Year'] + Luxembourg['Aggregate Year'] 

Malta['Month2'] = np.arange(len(Malta))
Malta['Year']  = '2020'
Malta['Aggregate Year'] = (Malta['Month2']/12).astype(int)
Malta['Year'] = Malta['Year'].astype(int)
Malta['Year Series'] = Malta['Year'] + Malta['Aggregate Year'] 

Netherlands['Month2'] = np.arange(len(Netherlands))
Netherlands['Year']  = '2020'
Netherlands['Aggregate Year'] = (Netherlands['Month2']/12).astype(int)
Netherlands['Year'] = Netherlands['Year'].astype(int)
Netherlands['Year Series'] = Netherlands['Year'] + Netherlands['Aggregate Year'] 

Poland['Month2'] = np.arange(len(Poland))
Poland['Year']  = '2020'
Poland['Aggregate Year'] = (Poland['Month2']/12).astype(int)
Poland['Year'] = Poland['Year'].astype(int)
Poland['Year Series'] = Poland['Year'] + Poland['Aggregate Year'] 

Portugal['Month2'] = np.arange(len(Portugal))
Portugal['Year']  = '2020'
Portugal['Aggregate Year'] = (Portugal['Month2']/12).astype(int)
Portugal['Year'] = Portugal['Year'].astype(int)
Portugal['Year Series'] = Portugal['Year'] + Portugal['Aggregate Year'] 

Slovakia['Month2'] = np.arange(len(Slovakia))
Slovakia['Year']  = '2020'
Slovakia['Aggregate Year'] = (Slovakia['Month2']/12).astype(int)
Slovakia['Year'] = Slovakia['Year'].astype(int)
Slovakia['Year Series'] = Slovakia['Year'] + Slovakia['Aggregate Year'] 

Slovenia['Month2'] = np.arange(len(Slovenia))
Slovenia['Year']  = '2020'
Slovenia['Aggregate Year'] = (Slovenia['Month2']/12).astype(int)
Slovenia['Year'] = Slovenia['Year'].astype(int)
Slovenia['Year Series'] = Slovenia['Year'] + Slovenia['Aggregate Year'] 

Spain['Month2'] = np.arange(len(Spain))
Spain['Year']  = '2020'
Spain['Aggregate Year'] = (Spain['Month2']/12).astype(int)
Spain['Year'] = Spain['Year'].astype(int)
Spain['Year Series'] = Spain['Year'] + Spain['Aggregate Year'] 

Sweden['Month2'] = np.arange(len(Sweden))
Sweden['Year']  = '2020'
Sweden['Aggregate Year'] = (Sweden['Month2']/12).astype(int)
Sweden['Year'] = Sweden['Year'].astype(int)
Sweden['Year Series'] = Sweden['Year'] + Sweden['Aggregate Year']
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
precip3 = pd.concat([Austria, Belgium, Bulgaria, Croatia, Cyprus, CzechRepublic, Denmark, Estonia, Finland, 
                   France, Germany, Greece, Hungary, Ireland, Latvia, Lithuania, Luxembourg, Malta, 
                   Netherlands, Poland, Portugal, Slovakia, Slovenia, Spain, Sweden])

# %%
precip4 = precip3[['Country','Year Series','Precip']]

# %%
precip4.head()
precip4['Precip'] = precip4['Precip'].astype('float')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
precip5 = precip4.groupby(['Country','Year Series'])['Precip'].mean()
#data.groupby('month', as_index=False).agg({"duration": "sum"})

# %%
precip5 = precip5.reset_index()

# %%
precip6 = precip5[(precip5['Year Series'] < 2036)]

# %%
precip6_min = precip6[(precip6['Year Series'] == 2020)] 
precip6_max = precip6[(precip6['Year Series'] == 2035)]

# %%
precip6_merge = precip6_min.merge(precip6_max,on='Country',how='left')

# %%
precip6_merge.rename({'Precip_x': '2020 Precip', 'Precip_y': '2038 Precip'}, axis=1, inplace=True)
precip6_merge = precip6_merge[['Country','2020 Precip','2038 Precip']]

# %%
precip6_merge['Precip Increase'] = precip6_merge['2038 Precip'] - precip6_merge['2020 Precip']

# %%
precip6_merge
# Out:
#           Country  2020 Precip  2038 Precip  Precip Increase
# 0         Austria    69.705798    74.141334         4.435536
# 1         Belgium    83.236729    83.803790         0.567062
# 2        Bulgaria    51.479076    57.753580         6.274504
# 3         Croatia    65.092962    66.467928         1.374966
# 4          Cyprus    30.205027    35.645693         5.440666
# 5   CzechRepublic    68.093337    68.561286         0.467949
# 6         Denmark    80.928498    75.605805        -5.322692
# 7         Estonia    62.247865    61.084422        -1.163444
# 8         Finland    57.257382    58.516905         1.259523
# 9          France    69.851577    76.262272         6.410696
# 10        Germany    78.386425    82.592905         4.206480
# 11         Greece    41.946258    46.507308         4.561050
# 12        Hungary    67.571950    66.570342        -1.001609
# 13        Ireland    94.638936    95.020961         0.382025
# ...

# %%
precip6_merge.to_excel('/Users/ilyasozgur/Desktop/OutputforProject/Precip_Increase.xlsx')
